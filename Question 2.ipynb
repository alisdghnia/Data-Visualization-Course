# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

## Question 2
df1 = pd.read_excel('Combined.xlsx', sheet_name= 'Pasco')
df1.columns = ['Date', 'Number of Daily Cases', 'Moving Average']
df1.plot('Date', ['Number of Daily Cases', 'Moving Average'], title = 'Question 2', ylabel = 'Count')
plt.show()

# %%
df1.plot('Date', ['Number of Daily Cases', 'Moving Average'], xticks = [], ylabel = 'Count')
plt.show()
