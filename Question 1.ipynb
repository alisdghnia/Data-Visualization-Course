# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

## Question 1
df = pd.read_excel('2018 Data.xlsx')
plt.scatter(df['Perc with health Insurance'], df['Median Family Income'], c = 'green', marker = '*')
plt.show()

# %%
df.plot('Perc with health Insurance', 'Median Family Income', kind = 'scatter', marker = '*', color = 'purple', ylabel = 'Median Family Income in $',
        xlabel = 'Family with Health Insurance in %')
plt.show()
